# %% [markdown]
# Connected to Python 3.12.1

# %%
df = pd.read_csv('creditcard/creditcard_2023.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\monte\OneDrive\Pictures\Y.A.M\analise de frauldeIA\probabilidade.py:1
# ----> 1 df = pd.read_csv('creditcard/creditcard_2023.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('creditcard/creditcard_2023.csv')

# %%
print("Colunas do dataset:")
print(df.columns)
# Out:
# Colunas do dataset:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregue seu dataset a partir do arquivo CSV
df = pd.read_csv('creditcard/creditcard_2023.csv')

# Exibir os nomes das colunas
print("Colunas do dataset:")
print(df.columns)
# Exiba as primeiras linhas do DataFrame para entender sua estrutura
coluna = 'Amount'  # Escolha a coluna que deseja analisar (pode alterar para outra se necessário)

# Cálculo das estatísticas
media = df[coluna].mean()
mediana = df[coluna].median()
desvio_padrao = df[coluna].std()

# Exibir as estatísticas
print(f"Média: {media}")
print(f"Mediana: {mediana}")
print(f"Desvio Padrão: {desvio_padrao}")

# Gráfico de frequência
plt.figure(figsize=(10, 6))
sns.histplot(df[coluna], bins=30, kde=True)
plt.axvline(media, color='red', linestyle='dashed', linewidth=1, label='Média')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=1, label='Mediana')
plt.axvline(media + desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (+)')
plt.axvline(media - desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (-)')
plt.title('Histograma com Média, Mediana e Desvio Padrão')
plt.xlabel(coluna)
plt.ylabel('Frequência')
plt.legend()
plt.grid(True)
plt.show()

# Cálculo e exibição da frequência média (quantidade média de vezes que cada valor aparece)
frequencia_media = df[coluna].value_counts().mean()
print(f'Frequência média: {frequencia_media}')
# Out:
# Colunas do dataset:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
# Média: 12041.957634577848
# Mediana: 12030.15
# Desvio Padrão: 6919.6444494291845
# Frequência média: 1.122698599168781

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregue seu dataset a partir do arquivo CSV
df = pd.read_csv('creditcard/creditcard_2023.csv')

# Exibir os nomes das colunas
print("Colunas do dataset:")
print(df.columns)
# Exiba as primeiras linhas do DataFrame para entender sua estrutura
print(df.head())

# Escolher a coluna para análise (exemplo: 'Amount')
coluna = 'Amount'  # Pode ajustar para outra coluna relevante do dataset

# Cálculo das estatísticas
media = df[coluna].mean()
mediana = df[coluna].median()
desvio_padrao = df[coluna].std()

# Exibir as estatísticas
print(f"Média: {media}")
print(f"Mediana: {mediana}")
print(f"Desvio Padrão: {desvio_padrao}")

# Plotar histograma com média, mediana e desvio padrão
plt.figure(figsize=(10, 6))
sns.histplot(df[coluna], bins=30, kde=True)
plt.axvline(media, color='red', linestyle='dashed', linewidth=1, label='Média')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=1, label='Mediana')
plt.axvline(media + desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (+)')
plt.axvline(media - desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (-)')
plt.title('Histograma com Média, Mediana e Desvio Padrão')
plt.xlabel(coluna)
plt.ylabel('Frequência')
plt.legend()
plt.grid(True)
plt.show()

# Gráfico de frequência (quantidade de ocorrências de cada valor)
plt.figure(figsize=(10, 6))
sns.histplot(df[coluna].value_counts(), bins=30, kde=True)
plt.title(f'Gráfico de Frequência - {coluna}')
plt.xlabel('Frequência')
plt.ylabel('Ocorrências')
plt.grid(True)
plt.show()

# Cálculo e exibição da frequência média (quantidade média de vezes que cada valor aparece)
frequencia_media = df[coluna].value_counts().mean()
print(f'Frequência média: {frequencia_media}')
# Out:
# Colunas do dataset:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]
# Média: 12041.957634577848
# Mediana: 12030.15
# Desvio Padrão: 6919.6444494291845
# Frequência média: 1.122698599168781

# %% [markdown]
# Connected to Python 3.12.1

# %%
print("Colunas do dataset:")
print(df.columns)
# Out:
# Colunas do dataset:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\monte\OneDrive\Pictures\Y.A.M\analise de frauldeIA\probabilidade.py:2
#       1 print("Colunas do dataset:")
# ----> 2 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregue seu dataset a partir do arquivo CSV
df = pd.read_csv('creditcard/creditcard_2023.csv')

# Exibir os nomes das colunas
print("Colunas do dataset:")
print(df.columns)
# Out:
# Colunas do dataset:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregue seu dataset a partir do arquivo CSV
df = pd.read_csv('creditcard/creditcard_2023.csv')

# Exibir os nomes das colunas
print("Colunas do dataset:")
print(df.columns)
# Exiba as primeiras linhas do DataFrame para entender sua estrutura
print(df.head())

# Escolher a coluna para análise (exemplo: 'Amount')
coluna = 'Amount'  # Pode ajustar para outra coluna relevante do dataset

# Cálculo das estatísticas
media = df[coluna].mean()
mediana = df[coluna].median()
desvio_padrao = df[coluna].std()

# Exibir as estatísticas
print(f"Média: {media}")
print(f"Mediana: {mediana}")
print(f"Desvio Padrão: {desvio_padrao}")

# Plotar histograma com média, mediana e desvio padrão
plt.figure(figsize=(10, 6))
sns.histplot(df[coluna], bins=30, kde=True)
plt.axvline(media, color='red', linestyle='dashed', linewidth=1, label='Média')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=1, label='Mediana')
plt.axvline(media + desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (+)')
plt.axvline(media - desvio_padrao, color='orange', linestyle='dashed', linewidth=1, label='Desvio Padrão (-)')
plt.title('Histograma com Média, Mediana e Desvio Padrão')
plt.xlabel(coluna)
plt.ylabel('Frequência')
plt.legend()
plt.grid(True)
plt.show()

# Gráfico de frequência (quantidade de ocorrências de cada valor)
plt.figure(figsize=(10, 6))
sns.histplot(df[coluna].value_counts(), bins=30, kde=True)
plt.title(f'Gráfico de Frequência - {coluna}')
plt.xlabel('Frequência')
plt.ylabel('Ocorrências')
plt.grid(True)
plt.show()

# Cálculo e exibição da frequência média (quantidade média de vezes que cada valor aparece)
frequencia_media = df[coluna].value_counts().mean()
print(f'Frequência média: {frequencia_media}')
# Out:
# Colunas do dataset:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]
# Média: 12041.957634577848
# Mediana: 12030.15
# Desvio Padrão: 6919.6444494291845
# Frequência média: 1.122698599168781
